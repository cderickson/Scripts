# %%
import pickle
import pandas as pd

with open('ALL_DECKS', 'rb') as f:
    data = pickle.load(f)

# See what type the pickle loaded as
print(type(data))

# Load into DataFrame (handles DataFrame, list of dicts, or dict of lists)
if isinstance(data, pd.DataFrame):
    df = data
else:
    df = pd.DataFrame(data)

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       5     data = pickle.load(f)
#       7 # Load into DataFrame (handles DataFrame, list of dicts, or dict of lists)
# ----> 8 print(data.dtypes)
#
# AttributeError: 'dict' object has no attribute 'dtypes'
